# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **This data was obtained by running a random policy on the robot. Then, the robot goes out of the scene and a snapshot is taken.**

# %%
empty_states = np.load("empty_states_couple.npy")

# %%
empty_states.shape
# Out:
# (271, 64, 64, 3)

# %%
for i in np.random.randint(0, len(empty_states), 10):
    plt.imshow(empty_states[i])
    plt.show()

# %% [markdown]
# **For each image we also have an image with the robot in the picture, before moving out. This can be useful in models that learn how to remove the robot from the picture.**

# %%
robot_states = np.load("states_couple.npy")
robot_states.shape
# Out:
# (271, 64, 64, 3)

# %%
for i in np.random.randint(0, len(empty_states), 10):
    plt.imshow(empty_states[i])
    plt.show()
    plt.imshow(robot_states[i])
    plt.show()
